# %% [markdown]
# ## Skeleton Code
#
# The code below provides a skeleton for the model building & training component of your project. You can add/remove/build on code however you see fit, this is meant as a starting point.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.utils import resample
import matplotlib.ticker as mtick
##Import any other stats/DL/ML packages you may need here. E.g. Keras, scikit-learn, etc.

# %% [markdown]
# ## Do some early processing of your metadata for easier model training:

# %%
## Below is some helper code to read all of your full image filepaths into a dataframe for easier manipulation
## Load the NIH data to all_xray_df
all_xray_df = pd.read_csv('/data/Data_Entry_2017.csv')
all_image_paths = {os.path.basename(x): x for x in 
                   glob(os.path.join('/data','images*', '*', '*.png'))}
print('Scans found:', len(all_image_paths), ', Total Headers', all_xray_df.shape[0])
all_xray_df['path'] = all_xray_df['Image Index'].map(all_image_paths.get)
all_xray_df.sample(3)
# Out:
# Scans found: 112120 , Total Headers 112120
#             Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 19268  00005097_000.png     No Finding            0        5097           21
# 16405  00004380_000.png     No Finding            0        4380           21
# 23517  00006230_009.png     No Finding            9        6230           83
#
#       Patient Gender View Position  OriginalImage[Width  Height]  \
# 19268              M            AP                 2500     2048
# 16405              M            PA                 2500     2048
# 23517              M            PA                 2500     2048
#
#        OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 19268                        0.171  0.171          NaN
# 16405                        0.171  0.171          NaN
# 23517                        0.168  0.168          NaN
#
#                                            path
# 19268  /data/images_003/images/00005097_000.png
# 16405  /data/images_003/images/00004380_000.png
# 23517  /data/images_003/images/00006230_009.png

# %%
## Here we can create a new column called 'pneumonia_class' that will allow us to look at 
## images with or without pneumonia for binary classification

# Todo
maplist=list(all_xray_df['Finding Labels'].map(lambda x: x.split('|') ))
 
df=pd.DataFrame(maplist)[0]
realList=pd.Series(df).drop_duplicates().tolist()
 
for item in realList:
    all_xray_df[item] = all_xray_df['Finding Labels'].map(lambda finding: 1 if item in finding else 0)
all_xray_df['pneumonia_class'] = all_xray_df['Pneumonia']
all_xray_df.sample(3)
# Out:
#             Image Index                    Finding Labels  Follow-up #  \
# 89916  00022330_000.png                        No Finding            0
# 83866  00020614_005.png                        No Finding            5
# 43124  00011136_002.png  Consolidation|Effusion|Pneumonia            2
#
#        Patient ID  Patient Age Patient Gender View Position  \
# 89916       22330           51              F            PA
# 83866       20614           34              F            AP
# 43124       11136           31              M            PA
#
#        OriginalImage[Width  Height]  OriginalImagePixelSpacing[x  ...  Nodule  \
# 89916                 2774     2991                        0.143  ...       0
# 83866                 3056     2544                        0.139  ...       0
# 43124                 2992     2991                        0.143  ...       0
#
#        Emphysema Atelectasis  Pleural_Thickening  Pneumothorax  Fibrosis  \
# 89916          0           0                   0             0         0
# 83866          0           0                   0             0         0
# 43124          0           0                   0             0         0
#
#        Consolidation  Edema  Pneumonia  pneumonia_class
# 89916              0      0          0                0
# 83866              0      0          0                0
# 43124              1      0          1                1
#
# [3 rows x 29 columns]

# %%
all_xray_df["pneumonia_class"].value_counts()
# Out:
# 0    110689
# 1      1431
# Name: pneumonia_class, dtype: int64

# %% [markdown]
# ## Create your training and testing data:

# %%
def create_splits(vargs):
    
    ## Either build your own or use a built-in library to split your original dataframe into two sets 
    ## that can be used for training and testing your model
    ## It's important to consider here how balanced or imbalanced you want each of those sets to be
    ## for the presence of pneumonia
    
    # Todo
    #I'll split it to 80 by 20
    msk = np.random.rand(len(vargs)) < 0.8
    
    train = vargs[msk]
    

    valid = vargs[~msk]

     # Separate majority and minority classes
    #seperate majority class from minority
    train_minor=train[train["pneumonia_class"]==1] 
    train_major=train[train["pneumonia_class"]==0] 
    df_minority_upsampled = resample(train_minor, 
                                     replace=True,     # sample with replacement
                                     n_samples=len(train_major),     # to match majority class
                                     random_state=123) # reproducible results
    # Combine majority class with upsampled minority class
    train_data = pd.concat([train_major, df_minority_upsampled])

    val_minor=valid[valid["pneumonia_class"]==1] 
    val_major=valid[valid["pneumonia_class"]==0] 
    df_minority_upsampled = resample(val_minor, 
                                     replace=True,     # sample with replacement
                                     n_samples=len(val_minor)*30,     # to match majority class
                                     random_state=123) # reproducible results
    val_data = pd.concat([val_major, df_minority_upsampled])
 

    
    return train_data, val_data
 
tr=create_splits(all_xray_df)[0]
vl=create_splits(all_xray_df)[1]

# %%
len(tr[tr["pneumonia_class"]==0] )
tr['pneumonia_class'].sum()/len(tr) #let's see the len rate of balanced train
# Out:
# 0.5

# %%
vl['pneumonia_class'].sum()/len(vl) #let's see the len rate of val
# Out:
# 0.2676278886035947

# %%
all_xray_df["pneumonia_class"]=all_xray_df["pneumonia_class"].astype(str)

# %% [markdown]
# # Now we can begin our model-building & training

# %% [markdown]
# #### First suggestion: perform some image augmentation on your data

# %%
from keras_preprocessing.image import ImageDataGenerator
def my_image_augmentation(vargs):
    
    ## recommendation here to implement a package like Keras' ImageDataGenerator
    ## with some of the built-in augmentations 
    
    ## keep an eye out for types of augmentation that are or are not appropriate for medical imaging data
    ## Also keep in mind what sort of augmentation is or is not appropriate for testing vs validation data
    
    ## STAND-OUT SUGGESTION: implement some of your own custom augmentation that's *not*
    ## built into something like a Keras package
    
    # Todo
    
    my_idg=ImageDataGenerator(rescale=1./255.,validation_split=0.2,zca_whitening=False,
                              rotation_range=0,fill_mode='reflect',zoom_range=0.0)
     
    return my_idg


def make_train_gen(vargs):
    
    
    ## Create the actual generators using the output of my_image_augmentation for your training data
    ## Suggestion here to use the flow_from_dataframe library, e.g.:
    gen=my_image_augmentation(all_xray_df)
    train_gen = gen.flow_from_dataframe(dataframe = all_xray_df, 
                                              directory="/data/images_010/images", 
                                              x_col = "Image Index",
                                              y_col = "pneumonia_class",
                                              class_mode = 'binary',
                                              target_size = (32,32), 
                                              batch_size = 128,
                                              subset='training',
                                              validate_filenames=True) 

    return train_gen


def make_val_gen(vargs):
    
     
    validation_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.2)
    val_gen = validation_datagen.flow_from_dataframe(dataframe = all_xray_df, 
                                              directory="/data/images_010/images", 
                                              x_col = "Image Index",
                                              y_col = "pneumonia_class",
                                              class_mode = 'binary',
                                              target_size = (32,32), 
                                                subset='validation',
                                              batch_size = 128) 
    
    
    return val_gen
train_gen=make_train_gen(all_xray_df)
val_gen=make_val_gen(all_xray_df)
# Out:
# /opt/conda/lib/python3.7/site-packages/keras_preprocessing/image/dataframe_iterator.py:273: UserWarning: Found 102120 invalid image filename(s) in x_col="Image Index". These filename(s) will be ignored.
#   .format(n_invalid, x_col)
# Found 8000 validated image filenames belonging to 2 classes.
# Found 2000 validated image filenames belonging to 2 classes.

# %%
## May want to pull a single large batch of random validation data for testing after each epoch:
valX, valY = val_gen.next()

# %%
## May want to look at some examples of our augmented training data. 
## This is helpful for understanding the extent to which data is being manipulated prior to training, 
## and can be compared with how the raw data look prior to augmentation

t_x, t_y = next(train_gen)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 16))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone')
    if c_y == 1: 
        c_ax.set_title('Pneumonia')
    else:
        c_ax.set_title('No Pneumonia')
    c_ax.axis('off')

# %% [markdown]
# ## Build your model:
#
# Recommendation here to use a pre-trained network downloaded from Keras for fine-tuning

# %%
from keras.layers import Dense, GlobalAveragePooling2D,Dropout
from keras.models import Model
from keras.optimizers import Adam

from keras.applications.resnet50 import ResNet50
def load_pretrained_model(vargs):
    
    # model = VGG16(include_top=True, weights='imagenet')
    # transfer_layer = model.get_layer(lay_of_interest)
    # vgg_model = Model(inputs = model.input, outputs = transfer_layer.output)
    
    # Todo
    

    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

            # freeze ResNet50 first 24 weights
    for layer in base_model.layers[:24]:
        layer.trainable = False
        return base_model
    
 
        base_model.add(layer)
        if layer.name in ['fc1', 'fc2']:
            base_model.add(Dropout(.5))


base_model=load_pretrained_model(all_xray_df)
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.7/site-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 1s 0us/step

# %%
from keras.optimizers import SGD, Adamax, Adagrad, RMSprop
def build_my_model(vargs):
    
    # my_model = Sequential()
    # ....add your pre-trained model, and then whatever additional layers you think you might
    # want for fine-tuning (Flatteen, Dense, Dropout, etc.)
    
    # if you want to compile your model within this function, consider which layers of your pre-trained model, 
    # you want to freeze before you compile 
    
    # also make sure you set your optimizer, loss function, and metrics to monitor
    
    # Todo

    
    
            # add new classification head
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dense(2, activation='sigmoid')(x)
    predictions = Dense(1, activation='sigmoid')(x)
    my_model = Model(inputs=base_model.input, outputs=predictions)   
    adam= Adam(lr= 0.0001, decay=0.000001)
    
    sgd = SGD(lr=0.0001)
    adax=Adamax(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07 )
    my_model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['binary_accuracy'])
    #my_model.summary()


    return my_model

my_model=build_my_model(all_xray_df)

## STAND-OUT Suggestion: choose another output layer besides just the last classification layer of your modele
## to output class activation maps to aid in clinical interpretation of your model's results

# %%
## Below is some helper code that will allow you to add checkpoints to your model,
## This will save the 'best' version of your model by comparing it to previous epochs of training

## Note that you need to choose which metric to monitor for your model's 'best' performance if using this code. 
## The 'patience' parameter is set to 10, meaning that your model will train for ten epochs without seeing
## improvement before quitting

# Todo

# weight_path="{}_my_model.best.hdf5".format('xray_class')

# checkpoint = ModelCheckpoint(weight_path, 
#                              monitor= CHOOSE_METRIC_TO_MONITOR_FOR_PERFORMANCE, 
#                              verbose=1, 
#                              save_best_only=True, 
#                              mode= CHOOSE_MIN_OR_MAX_FOR_YOUR_METRIC, 
#                              save_weights_only = True)

# early = EarlyStopping(monitor= SAME_AS_METRIC_CHOSEN_ABOVE, 
#                       mode= CHOOSE_MIN_OR_MAX_FOR_YOUR_METRIC, 
#                       patience=10)

# callbacks_list = [checkpoint, early]

from keras.callbacks import ModelCheckpoint, EarlyStopping
weight_path="{}_my_model.best.hdf5".format('xray_class')



checkpoint = ModelCheckpoint(weight_path, 
                              monitor= 'val_binary_accuracy',
                              verbose=1, 
                              save_best_only=True, 
                             #mode: For val_acc, this should be max, for val_loss this should be min
                              mode= "max", 
                              save_weights_only = True)
early = EarlyStopping(monitor= "val_loss", 
                      #n auto mode, the direction is automatically inferred from the name of the monitored quantity.
                       mode= "auto", 
                       patience=15)

callbacks_list = [checkpoint, early]
callback = EarlyStopping(monitor='loss', patience=8)

# %% [markdown]
# ### Start training!

# %%
## train your model

# Todo

# history = my_model.fit_generator(train_gen, 
#                           validation_data = (valX, valY), 
#                           epochs = , 
#                           callbacks = callbacks_list)

history = my_model.fit_generator(train_gen, 
                         validation_data = (valX, valY), 
                           epochs =40, 
                            class_weight='auto', #try to balance the labels
                           callbacks = callbacks_list)
# Out:
# Epoch 1/40
# 63/63 [==============================] - 132s 2s/step - loss: 1.0077 - binary_accuracy: 0.0121 - val_loss: 0.7477 - val_binary_accuracy: 0.0312
#
# Epoch 00001: val_binary_accuracy improved from -inf to 0.03125, saving model to xray_class_my_model.best.hdf5
# Epoch 2/40
# 63/63 [==============================] - 111s 2s/step - loss: 0.9921 - binary_accuracy: 0.0122 - val_loss: 0.7330 - val_binary_accuracy: 0.0312
#
# Epoch 00002: val_binary_accuracy did not improve from 0.03125
# Epoch 3/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.9816 - binary_accuracy: 0.0126 - val_loss: 0.7144 - val_binary_accuracy: 0.0312
#
# Epoch 00003: val_binary_accuracy did not improve from 0.03125
# Epoch 4/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.9652 - binary_accuracy: 0.0129 - val_loss: 0.6859 - val_binary_accuracy: 0.9688
#
# Epoch 00004: val_binary_accuracy improved from 0.03125 to 0.96875, saving model to xray_class_my_model.best.hdf5
# Epoch 5/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.9522 - binary_accuracy: 0.0140 - val_loss: 0.6842 - val_binary_accuracy: 0.9688
#
# Epoch 00005: val_binary_accuracy did not improve from 0.96875
# Epoch 6/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.9391 - binary_accuracy: 0.0149 - val_loss: 0.6824 - val_binary_accuracy: 0.9688
#
# Epoch 00006: val_binary_accuracy did not improve from 0.96875
# Epoch 7/40
# 63/63 [==============================] - 113s 2s/step - loss: 0.9256 - binary_accuracy: 0.0175 - val_loss: 0.6807 - val_binary_accuracy: 0.9688
#
# Epoch 00007: val_binary_accuracy did not improve from 0.96875
# Epoch 8/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.9109 - binary_accuracy: 0.0195 - val_loss: 0.6790 - val_binary_accuracy: 0.9688
#
# Epoch 00008: val_binary_accuracy did not improve from 0.96875
# Epoch 9/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.9007 - binary_accuracy: 0.0259 - val_loss: 0.6777 - val_binary_accuracy: 0.9609
#
# Epoch 00009: val_binary_accuracy did not improve from 0.96875
# Epoch 10/40
# 63/63 [==============================] - 113s 2s/step - loss: 0.8877 - binary_accuracy: 0.0286 - val_loss: 0.6771 - val_binary_accuracy: 0.9375
#
# Epoch 00010: val_binary_accuracy did not improve from 0.96875
# Epoch 11/40
# 63/63 [==============================] - 113s 2s/step - loss: 0.8756 - binary_accuracy: 0.0324 - val_loss: 0.6870 - val_binary_accuracy: 0.7969
#
# Epoch 00011: val_binary_accuracy did not improve from 0.96875
# Epoch 12/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.8653 - binary_accuracy: 0.0391 - val_loss: 0.7439 - val_binary_accuracy: 0.5312
#
# Epoch 00012: val_binary_accuracy did not improve from 0.96875
# Epoch 13/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.8553 - binary_accuracy: 0.0461 - val_loss: 0.7658 - val_binary_accuracy: 0.3594
#
# Epoch 00013: val_binary_accuracy did not improve from 0.96875
# Epoch 14/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.8450 - binary_accuracy: 0.0571 - val_loss: 0.7538 - val_binary_accuracy: 0.2891
#
# Epoch 00014: val_binary_accuracy did not improve from 0.96875
# Epoch 15/40
# 63/63 [==============================] - 117s 2s/step - loss: 0.8369 - binary_accuracy: 0.0600 - val_loss: 0.7312 - val_binary_accuracy: 0.3281
#
# Epoch 00015: val_binary_accuracy did not improve from 0.96875
# Epoch 16/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.8281 - binary_accuracy: 0.0725 - val_loss: 0.7223 - val_binary_accuracy: 0.3672
#
# Epoch 00016: val_binary_accuracy did not improve from 0.96875
# Epoch 17/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.8195 - binary_accuracy: 0.0841 - val_loss: 0.7316 - val_binary_accuracy: 0.3047
#
# Epoch 00017: val_binary_accuracy did not improve from 0.96875
# Epoch 18/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.8111 - binary_accuracy: 0.0984 - val_loss: 0.7419 - val_binary_accuracy: 0.2969
#
# Epoch 00018: val_binary_accuracy did not improve from 0.96875
# Epoch 19/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.8030 - binary_accuracy: 0.1147 - val_loss: 0.7474 - val_binary_accuracy: 0.2891
#
# Epoch 00019: val_binary_accuracy did not improve from 0.96875
# Epoch 20/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.7949 - binary_accuracy: 0.1224 - val_loss: 0.7414 - val_binary_accuracy: 0.2656
#
# Epoch 00020: val_binary_accuracy did not improve from 0.96875
# Epoch 21/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.7882 - binary_accuracy: 0.1494 - val_loss: 0.7430 - val_binary_accuracy: 0.3125
#
# Epoch 00021: val_binary_accuracy did not improve from 0.96875
# Epoch 22/40
# 63/63 [==============================] - 117s 2s/step - loss: 0.7816 - binary_accuracy: 0.1690 - val_loss: 0.7408 - val_binary_accuracy: 0.3359
#
# Epoch 00022: val_binary_accuracy did not improve from 0.96875
# Epoch 23/40
# 63/63 [==============================] - 116s 2s/step - loss: 0.7766 - binary_accuracy: 0.1889 - val_loss: 0.7394 - val_binary_accuracy: 0.3516
#
# Epoch 00023: val_binary_accuracy did not improve from 0.96875
# Epoch 24/40
# 63/63 [==============================] - 117s 2s/step - loss: 0.7698 - binary_accuracy: 0.2154 - val_loss: 0.7454 - val_binary_accuracy: 0.3438
#
# Epoch 00024: val_binary_accuracy did not improve from 0.96875
# Epoch 25/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.7643 - binary_accuracy: 0.2438 - val_loss: 0.7316 - val_binary_accuracy: 0.3750
#
# Epoch 00025: val_binary_accuracy did not improve from 0.96875
# Epoch 26/40
# 63/63 [==============================] - 116s 2s/step - loss: 0.7573 - binary_accuracy: 0.2777 - val_loss: 0.7448 - val_binary_accuracy: 0.3516
#
# Epoch 00026: val_binary_accuracy did not improve from 0.96875
# Epoch 27/40
# 63/63 [==============================] - 116s 2s/step - loss: 0.7527 - binary_accuracy: 0.3016 - val_loss: 0.7475 - val_binary_accuracy: 0.3516
#
# Epoch 00027: val_binary_accuracy did not improve from 0.96875
# Epoch 28/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.7476 - binary_accuracy: 0.3264 - val_loss: 0.7498 - val_binary_accuracy: 0.3359
#
# Epoch 00028: val_binary_accuracy did not improve from 0.96875
# Epoch 29/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.7424 - binary_accuracy: 0.3541 - val_loss: 0.7449 - val_binary_accuracy: 0.3516
#
# Epoch 00029: val_binary_accuracy did not improve from 0.96875
# Epoch 30/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.7373 - binary_accuracy: 0.3772 - val_loss: 0.7411 - val_binary_accuracy: 0.3906
#
# Epoch 00030: val_binary_accuracy did not improve from 0.96875
# Epoch 31/40
# 63/63 [==============================] - 115s 2s/step - loss: 0.7335 - binary_accuracy: 0.4017 - val_loss: 0.7367 - val_binary_accuracy: 0.3594
#
# Epoch 00031: val_binary_accuracy did not improve from 0.96875
# Epoch 32/40
# 63/63 [==============================] - 117s 2s/step - loss: 0.7295 - binary_accuracy: 0.4201 - val_loss: 0.7325 - val_binary_accuracy: 0.4062
#
# Epoch 00032: val_binary_accuracy did not improve from 0.96875
# Epoch 33/40
# 63/63 [==============================] - 117s 2s/step - loss: 0.7263 - binary_accuracy: 0.4425 - val_loss: 0.7282 - val_binary_accuracy: 0.4062
#
# Epoch 00033: val_binary_accuracy did not improve from 0.96875
# Epoch 34/40
# 63/63 [==============================] - 112s 2s/step - loss: 0.7214 - binary_accuracy: 0.4780 - val_loss: 0.7251 - val_binary_accuracy: 0.4453
#
# Epoch 00034: val_binary_accuracy did not improve from 0.96875
# Epoch 35/40
# 63/63 [==============================] - 112s 2s/step - loss: 0.7176 - binary_accuracy: 0.4967 - val_loss: 0.7222 - val_binary_accuracy: 0.4453
#
# Epoch 00035: val_binary_accuracy did not improve from 0.96875
# Epoch 36/40
# 63/63 [==============================] - 112s 2s/step - loss: 0.7131 - binary_accuracy: 0.5156 - val_loss: 0.7153 - val_binary_accuracy: 0.4844
#
# Epoch 00036: val_binary_accuracy did not improve from 0.96875
# Epoch 37/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.7086 - binary_accuracy: 0.5422 - val_loss: 0.7149 - val_binary_accuracy: 0.4844
#
# Epoch 00037: val_binary_accuracy did not improve from 0.96875
# Epoch 38/40
# 63/63 [==============================] - 112s 2s/step - loss: 0.7067 - binary_accuracy: 0.5619 - val_loss: 0.7127 - val_binary_accuracy: 0.5391
#
# Epoch 00038: val_binary_accuracy did not improve from 0.96875
# Epoch 39/40
# 63/63 [==============================] - 112s 2s/step - loss: 0.7026 - binary_accuracy: 0.5863 - val_loss: 0.7090 - val_binary_accuracy: 0.5469
#
# Epoch 00039: val_binary_accuracy did not improve from 0.96875
# Epoch 40/40
# 63/63 [==============================] - 114s 2s/step - loss: 0.6988 - binary_accuracy: 0.6026 - val_loss: 0.7029 - val_binary_accuracy: 0.6016
#
# Epoch 00040: val_binary_accuracy did not improve from 0.96875

# %% [markdown]
# ##### After training for some time, look at the performance of your model by plotting some performance statistics:
#
# Note, these figures will come in handy for your FDA documentation later in the project

# %%
## After training, make some predictions to assess your model's overall performance
## Note that detecting pneumonia is hard even for trained expert radiologists, 
## so there is no need to make the model perfect.
my_model.load_weights(weight_path)
pred_Y = my_model.predict(valX, batch_size = 32, verbose = True)
# Out:
# 128/128 [==============================] - 2s 17ms/step

# %%
def plot_auc(t_y, p_y):
    
    ## Hint: can use scikit-learn's built in functions here like roc_curve
    
    # Todo
    from sklearn import metrics
    #give me the maximum values for roc plottin
 

    #fpr, tpr, thresholds = metrics.roc_curve(t_y, p_y, pos_label=1)

    
    fpr, tpr, thresholds = metrics.roc_curve(t_y,p_y, pos_label=1)


    plt.plot(fpr,tpr,label="data 1, auc=")
    plt.legend(loc=4)
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')

    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])

    plt.show()    

    
    return ( fpr,tpr)

## what other performance statistics do you want to include here besides AUC? 

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix,precision_recall_curve,average_precision_score
def cal_f1_score(lbl_true, lbl_pred):

    # Todo
    #get the average squared difference between the estimated values and the actual value.
    #accuracy=mean_squared_error(lbl_true, lbl_pred)
    accuracy=accuracy_score(lbl_true, lbl_pred)

    # precision tp / (tp + fp)
    precision = precision_score(lbl_true, lbl_pred, average="macro")
    # recall: tp / (tp + fn)
    recall = recall_score(lbl_true, lbl_pred, average="macro")
    # f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(lbl_true, lbl_pred, average="macro")
    print('Accuracy: {}'.format(accuracy))
    print('Precision: {}'.format(precision))
    print('Recall: {}'.format(recall))
    print('fscore: {}'.format(f1))
    
    prec, rec, threshold =precision_recall_curve(lbl_true, lbl_pred)
    plt.title('Plot Precision Recall')
    plt.plot(prec, rec, 'b', label = 'score = %0.2f' % average_precision_score(lbl_true,lbl_pred))
    return True

    
#Also consider plotting the history of your model training:

def plot_history(history):
    
    # Todo
    # plot the training loss and accuracy
 
    print(history.history.keys())
   
    plt.plot(history.history['binary_accuracy'])
    plt.plot(history.history['val_binary_accuracy'])
    plt.title('Training   Accuracy on Dataset')
    plt.ylabel('accuracy')
    plt.xlabel('epoch #')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

    
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Training  loss on Dataset')
    plt.ylabel('loss')
    plt.xlabel('epoch #')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
    return plt.savefig("Hplot.png")

 
    
def f1_fomurlar(t_y, p_y):
    prec, recall, threshold = precision_recall_curve(t_y, p_y)
    return 2*(prec*recall)/(prec+recall), prec, recall, threshold

# %%
#cal_f1_score(valY, pred_Y)

# LET'S HAVE OUR PROBABILITY CLASSES
#get median of predicted class
threshold=np.median(pred_Y)

cut = threshold    
y_pred_prob = np.zeros_like(pred_Y)    # initialise a matrix full with zeros
y_pred_prob[pred_Y > cut] = 1   #subsitute a 1 if value is above median prediction 

from sklearn.metrics import mean_squared_error
mse=mean_squared_error(valY, y_pred_prob)
print(mse)
# Out:
# 0.1171875

# %%
## plot figures

# Todo
plt.title(' roc_curve') 
plot_auc(valY,y_pred_prob)
plt.show()    

 
cal_f1_score(valY,y_pred_prob)
plt.show()


plot_history(history)
plt.show()
# Out:
# Accuracy: 0.8828125
# Precision: 0.4829059829059829
# Recall: 0.45564516129032256
# fscore: 0.46887966804979253
# dict_keys(['val_loss', 'val_binary_accuracy', 'loss', 'binary_accuracy'])

# %% [markdown]
# Once you feel you are done training, you'll need to decide the proper classification threshold that optimizes your model's performance for a given metric (e.g. accuracy, F1, precision, etc.  You decide)

# %%
print(classification_report(valY, y_pred_prob ))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.91      0.94       124
#          1.0       0.00      0.00      0.00         4
#
#     accuracy                           0.88       128
#    macro avg       0.48      0.46      0.47       128
# weighted avg       0.94      0.88      0.91       128

# %%
f1, prec, recall, thresh= f1_fomurlar(valY, pred_Y)
 

matrix_df = pd.DataFrame({'f1-score':f1[:6] , 'prec':prec[:6] , 'recall':recall[:6], 'thresholds':thresh})

# %%
matrix_df
# Out:
#    f1-score      prec  recall  thresholds
# 0  0.060606  0.031250    1.00    0.496134
# 1  0.057143  0.029703    0.75    0.496134
# 2  0.054054  0.028571    0.50    0.496134
# 3       NaN  0.000000    0.00    0.496134
# 4       NaN  0.000000    0.00    0.496134
# 5       NaN  0.000000    0.00    0.496134

# %%
axs = pd.plotting.scatter_matrix(matrix_df, alpha=0.2, figsize=(15,15), diagonal='kde')

# %%
BestThreshold = matrix_df.iloc[matrix_df['f1-score'].idxmax()]['thresholds']
print('The maximum score is :', matrix_df['f1-score'].max())
print('The best threshold is :', BestThreshold)
b
# Out:
# The maximum score is : 0.06060606060606061
# The best threshold is : 0.4961337745189667
# array([0.49613377, 0.49613383, 0.4961339 , 0.49613395, 0.496134  ,
#        0.49613413], dtype=float32)

# %%
scores=matrix_df['f1-score'].values

#impute the NaN
scores[np.isnan(scores)] = np.median(thresholds[~np.isnan(thresholds)])

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(scores ,thresholds)
ax.set_xlabel('thresholds')
ax.set_ylabel('f1_score')
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))

# %%
## Let's look at some examples of true vs. predicted with our best model: 

# Todo

# fig, m_axs = plt.subplots(10, 10, figsize = (16, 16))
# i = 0
# for (c_x, c_y, c_ax) in zip(valX[0:100], testY[0:100], m_axs.flatten()):
#     c_ax.imshow(c_x[:,:,0], cmap = 'bone')
#     if c_y == 1: 
#         if pred_Y[i] > YOUR_THRESHOLD:
#             c_ax.set_title('1, 1')
#         else:
#             c_ax.set_title('1, 0')
#     else:
#         if pred_Y[i] > YOUR_THRESHOLD: 
#             c_ax.set_title('0, 1')
#         else:
#             c_ax.set_title('0, 0')
#     c_ax.axis('off')
#     i=i+1

# %%
# Todo
YOUR_THRESHOLD = threshold
fig, m_axs = plt.subplots(8, 8, figsize = (16, 16))
i = 0
for (c_x, c_y, c_ax) in zip(valX[0:64], valY[0:64], m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone')
    if c_y == 1: 
        if pred_Y[i] > YOUR_THRESHOLD:
            c_ax.set_title('1, 1')
        else:
            c_ax.set_title('1, 0')
    else:
        if pred_Y[i] > YOUR_THRESHOLD: 
            c_ax.set_title('0, 1')
        else:
            c_ax.set_title('0, 0')
    c_ax.axis('off')
    i=i+1

# %%
## Just save model architecture to a .json:

model_json = my_model.to_json()
with open("my_model.json", "w") as json_file:
    json_file.write(model_json)
